# %%
import librosa
import librosa.display
import pandas as pd
import numpy as np

from os import listdir
from os.path import isfile, join
import csv

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data.csv')

# %%
df.loc[df['label'] == 'flu', 'label'] = 'Flauta'
df.loc[df['label'] == 'gel', 'label'] = 'Guitarra'
df.loc[df['label'] == 'pia', 'label'] = 'Piano'
df.loc[df['label'] == 'sax', 'label'] = 'Saxofone'
df.loc[df['label'] == 'tru', 'label'] = 'Trompete'
df.loc[df['label'] == 'vio', 'label'] = 'Violino'

# %%
df.label.unique()
# Out:
# array(['Flauta', 'Guitarra', 'Piano', 'Saxofone', 'Trompete', 'Violino'],
#       dtype=object)

# %%
df.shape

# %%
sns.boxplot(data=df, x="age", y="class")

# %%
for col in ['rms', 'spectral_centroid', 'spectral_bandwidth', 'rolloff',
       'zero_crossing_rate', 'mfcc1', 'mfcc2', 'mfcc3', 'mfcc4', 'mfcc5',
       'mfcc6', 'mfcc7', 'mfcc8', 'mfcc9', 'mfcc10', 'mfcc11', 'mfcc12',
       'mfcc13', 'mfcc14', 'mfcc15', 'mfcc16', 'mfcc17', 'mfcc18', 'mfcc19',
       'mfcc20']:
       sns.histplot(data=df, x=col, hue="label")
       plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21828/1366919405.py in <module>
#       5        'mfcc20']:
#       6        sns.histplot(data=df, x=col, hue="label")
# ----> 7        plt.show()
#
# c:\Users\gabis\Anaconda3\envs\sigproc\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     366     """
#     367     _warn_if_gui_out_of_main_thread()
# --> 368     return _backend_mod.show(*args, **kwargs)
#     369
#     370
#
# c:\Users\gabis\Anaconda3\envs\sigproc\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
for col in ['rms', 'spectral_centroid', 'spectral_bandwidth', 'rolloff',
       'zero_crossing_rate', 'mfcc1', 'mfcc2', 'mfcc3', 'mfcc4', 'mfcc5',
       'mfcc6', 'mfcc7', 'mfcc8', 'mfcc9', 'mfcc10', 'mfcc11', 'mfcc12',
       'mfcc13', 'mfcc14', 'mfcc15', 'mfcc16', 'mfcc17', 'mfcc18', 'mfcc19',
       'mfcc20']:
       fig = sns.histplot(data=df, x=col, hue="label", element='poly')
       # fig.
       fig.set(title=col)
       plt.show()

# %%
for col in ['rms', 'spectral_centroid', 'spectral_bandwidth', 'rolloff',
       'zero_crossing_rate', 'mfcc1', 'mfcc2', 'mfcc3', 'mfcc4', 'mfcc5',
       'mfcc6', 'mfcc7', 'mfcc8', 'mfcc9', 'mfcc10', 'mfcc11', 'mfcc12',
       'mfcc13', 'mfcc14', 'mfcc15', 'mfcc16', 'mfcc17', 'mfcc18', 'mfcc19',
       'mfcc20']:
       sns.violinplot(data=df, y=col, x="label")
       plt.show()

# %%
for col in ['rms', 'spectral_centroid', 'spectral_bandwidth', 'rolloff',
       'zero_crossing_rate', 'mfcc1', 'mfcc2', 'mfcc3', 'mfcc4', 'mfcc5',
       'mfcc6', 'mfcc7', 'mfcc8', 'mfcc9', 'mfcc10', 'mfcc11', 'mfcc12',
       'mfcc13', 'mfcc14', 'mfcc15', 'mfcc16', 'mfcc17', 'mfcc18', 'mfcc19',
       'mfcc20']:
       sns.boxplot(data=df, y=col, x="label")
       plt.show()

# %%
plt.figure(figsize=(10,5))
fig = sns.histplot(data=df_shuffle, x='rms', hue="label", element='poly')
fig.set_ylabel('Frequência')
fig.set_xlabel('Valor')
fig.set(title='Root Mean Square')
plt.savefig('../imagens/cols/rms.png', bbox_inches='tight')
plt.show()

# %%
df.describe()

# %%
for i in df.label.unique():
    print(i, df[df.label == i].describe())

# %%
plt.figure(figsize=(10,5))
fig = sns.violinplot(data=df, y='mfcc20', x="label")
fig.set_ylabel('Valores')
fig.set(xlabel = None)
fig.set(title='MFCC 20')
plt.savefig('../imagens/cols/mfcc20.png', bbox_inches='tight')
plt.show()

# %%
df.columns
# Out:
# Index(['filename', 'rms', 'spectral_centroid', 'spectral_bandwidth', 'rolloff',
#        'zero_crossing_rate', 'mfcc1', 'mfcc2', 'mfcc3', 'mfcc4', 'mfcc5',
#        'mfcc6', 'mfcc7', 'mfcc8', 'mfcc9', 'mfcc10', 'mfcc11', 'mfcc12',
#        'mfcc13', 'mfcc14', 'mfcc15', 'mfcc16', 'mfcc17', 'mfcc18', 'mfcc19',
#        'mfcc20', 'label'],
#       dtype='object')
