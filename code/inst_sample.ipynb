# %%
import librosa
import librosa.display
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from playsound import playsound
# %matplotlib inline

# %% [markdown]
# ## flauta

# %%
#load arquivo wav
#stereo

x_flute, sr = librosa.load('../audio_data/instrument_sample/Flute.nonvib.ff.A4.stereo.wav', sr = None)

# %%
playsound('../audio_data/instrument_sample/Flute.nonvib.ff.A4.stereo.wav')

# %%
# formato de onda no dominio do tempo
plt.figure(figsize=(10,5))
librosa.display.waveshow(x_flute, sr =sr, color='grey')
plt.title('Flauta')
# plt.savefig('wave_big.png', bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Flauta')

# %%
x_flute.shape
# Out:
# (105003,)

# %%
# formato de onda no dominio do tempo
plt.figure(figsize=(9,7))
librosa.display.waveshow(x_flute[50000:50300], sr =sr, color='grey')
plt.title('Flauta')
plt.savefig('../images/code_generated/inst_samples/flu_wave.png', bbox_inches='tight')

# %% [markdown]
# ## sax

# %%
#load arquivo wav
#stereo

x_sax, sr = librosa.load('../audio_data/instrument_sample/SopSax.nonvib.ff.A4.stereo.wav', sr = None)

# %%
playsound('../audio_data/instrument_sample/SopSax.nonvib.ff.A4.stereo.wav')

# %%
# formato de onda no dominio do tempo
plt.figure(figsize=(10,5))
librosa.display.waveshow(x_sax, sr =sr, color='grey')
plt.title('Saxofone')
# plt.savefig('wave_big.png', bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Saxofone')

# %%
# formato de onda no dominio do tempo
plt.figure(figsize=(9,7))
librosa.display.waveshow(x_sax[50000:50300], sr =sr, color='grey')
plt.title('Saxofone')
plt.savefig('../images/code_generated/inst_samples/sax_wave.png', bbox_inches='tight')

# %% [markdown]
# ## trompete

# %%
#load arquivo wav
#stereo

x_tru, sr = librosa.load('../audio_data/instrument_sample/Trumpet.novib.ff.A4.stereo.wav', sr = None)
playsound('../audio_data/instrument_sample/Trumpet.novib.ff.A4.stereo.wav')

# %%
# formato de onda no dominio do tempo
plt.figure(figsize=(10,5))
librosa.display.waveshow(x_tru, sr =sr, color='grey')
plt.title('Trompete')
# plt.savefig('wave_big.png', bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Trompete')

# %%
# formato de onda no dominio do tempo
plt.figure(figsize=(9,7))
librosa.display.waveshow(x_tru[50000:50300], sr =sr, color='grey')
plt.title('Trompete')
plt.savefig('../images/code_generated/inst_samples/tru_wave.png', bbox_inches='tight')

# %% [markdown]
# ## violin

# %%
#load arquivo wav
#stereo

x_vio, sr = librosa.load('../audio_data/instrument_sample/Violin.arco.ff.sulG.A4.stereo.wav', sr = 44100)
# playsound('../audio_data/instrument_sample/Violin.arco.ff.sulG.A4.stereo.wav')

# %%
# formato de onda no dominio do tempo
plt.figure(figsize=(10,5))
librosa.display.waveshow(x_vio, sr =sr, color='grey')
plt.title('Violino')
# plt.savefig('wave_big.png', bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Violino')

# %%
# formato de onda no dominio do tempo
plt.figure(figsize=(9,7))
librosa.display.waveshow(x_vio[50000:50300], sr =sr, color='grey')
plt.title('Violino')
plt.savefig('../images/code_generated/inst_samples/vio_wave.png', bbox_inches='tight')

# %% [markdown]
# ## sum

# %%
print(len(x_vio[:105003]), len(x_flute[:105003]), len(x_sax[:105003]),  len(x_tru[:105003]))
# Out:
# 105003 105003 105003 105003

# %%
df = pd.DataFrame({'vio': x_vio[:105003], 'tru':x_tru[:105003], 'flu': x_flute[:105003], 'sax': x_sax[:105003]})

# %%
sum_all = df.sum(axis=1)

# %%
a = np.array(sum_all)

# %%
# formato de onda no dominio do tempo
plt.figure(figsize=(10,5))
librosa.display.waveshow(a, sr =sr, color='grey')
plt.title('Soma')
# plt.savefig('wave_big.png', bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Soma')

# %%
# formato de onda no dominio do tempo
plt.figure(figsize=(9,7))
librosa.display.waveshow(a[50000:50300], sr =sr, color='grey')
plt.title('Soma')
plt.savefig('../images/code_generated/inst_samples/sum_wave.png', bbox_inches='tight')

# %%
# fig, [ax1, ax2, ax3, ax4, ax5] = plt.subplots(5, 1, sharex=True)
plt.figure(figsize=(10, 10))

plt.subplot(5, 1, 1)
librosa.display.waveshow(x_flute[50000:50400], sr =sr, color='grey')
plt.title('Flauta')

plt.subplot(5, 1, 2)
librosa.display.waveshow(x_sax[50000:50400], sr =sr, color='grey')
plt.title('Saxofone')

plt.subplot(5, 1, 3)
librosa.display.waveshow(x_tru[50000:50400], sr =sr, color='grey')
plt.title('Trompete')

plt.subplot(5, 1, 4)
librosa.display.waveshow(x_vio[50000:50400], sr =sr, color='grey')
plt.title('Violino')

plt.subplot(5, 1, 5)
librosa.display.waveshow(a[50000:50400], sr =sr, color='grey')
plt.title('Soma dos sinais')
plt.tight_layout()
plt.savefig('../images/code_generated/inst_samples/sum_subplot.png', bbox_inches='tight')
plt.show()
